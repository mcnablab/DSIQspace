# %%
import numpy as np
import nibabel as nib
import dsiadapt as dsi
from dipy.viz import fvtk
from dipy.data import get_sphere
import dsitool as dst
import dipy.reconst.dti as dti
import dipy.core.gradients as grad

# %pylab inline
np.set_printoptions(threshold=numpy.nan)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Four datasets
files = np.array(['DSI17_exvivo_cc', 'DSI15_exvivo_cc', 'DSI11_exvivo_cc', 'DSI11_invivo_cc'])

# %%
# Estimate diffusion rates using DTI fitting
rd = np.zeros(files.shape[0])
mdd = np.zeros(files.shape[0])
for ii in np.arange(files.shape[0]):
    filename = files[ii]
    data = dst.loaddata(filename);
    gtab = dst.loadgtab(filename);
    
    mask = mask3000 = gtab.bvals <= 3000; # Use only data with bvals less than 3000
    datamask = data[:, :, :, mask]
    gtabmask = grad.gradient_table_from_bvals_bvecs(gtab.bvals[mask], gtab.bvecs[mask, :])
    disp(gtabmask.bvals.shape) # Number of measurements used for DTI fitting
    
    tensormodel = dti.TensorModel(gtabmask)
    tensorfit = tensormodel.fit(datamask)
    rd[ii] = tensorfit.ad.mean()
    
    bigdelta, smalldelta = dst.loadtime(filename);
    mdd[ii] = np.sqrt(6 * rd[ii] * (bigdelta - smalldelta / 3))
# Out:
# 81
# 33
# 19
# 81

# %%
# Diffusion rate in the principle orientation in mm2/s
rd[0], rd[1], rd[2], rd[3]
# Out:
# (0.00018919397757426003,
#  0.00024257107809686298,
#  0.00018320991141977124,
#  0.0013544552376886991)

# %%
# Mean displacement distnace in the principle orientation in mm
mdd[0], mdd[1], mdd[2], mdd[3]
# Out:
# (0.0052014169985802119,
#  0.0058896234317527803,
#  0.005118497565988216,
#  0.01161480700114274)

# %%
# For ex vivo, use the estimation from DSI17 since it has the most DWIs among the three datasets
mdd[1] = mdd[0]
mdd[2] = mdd[0]

# %%
# Compute field-of-view (FOV)
fov = np.zeros(files.shape[0])
for ii in np.arange(files.shape[0]):
    filename = files[ii]
    data = dst.loaddata(filename);
    gtab = dst.loadgtab(filename);
    bigdelta, smalldelta = dst.loadtime(filename);
    
    bmax = gtab.bvals.max(); # Unit: s/mm2
    qmax = np.sqrt(bmax / (bigdelta - smalldelta / 3)) / (2 * np.pi); # Unit:mm-1
    deltaq = qmax / dsi.create_qtable(gtab).max(); # Unit: mm-1
    fov[ii] = 1 / deltaq; # Unit: mm

# %%
fov[0], fov[1], fov[2], fov[3]
# Out:
# (0.044765146562120356,
#  0.039169503241855308,
#  0.027978216601325222,
#  0.040476589908005262)

# %%
# Four datasets
files = np.array(['DSI17_exvivo_cc'])

# %%
qgridsz = 201; # Q-space grid size with extensive zero padding for better visualization
for ii in np.arange(files.shape[0]):
    filename = files[ii]
    data = dst.loaddata(filename);
    gtab = dst.loadgtab(filename);
    
    hannwidth = np.inf;
    integdist = mdd[ii];
    rend = np.round(integdist / fov[ii] * qgridsz);
    dsimodel = dsi.DiffusionSpectrumModel(gtab, qgrid_size=qgridsz, filter_width=hannwidth, r_start=0, r_end=rend, r_step=0.2);
    dsifit = dsimodel.fit(data);
    pdf = dsifit.pdf();
    pdf = pdf / pdf.sum() * 10**6; # Normalize PDF such that its summation is 1. 
                                   #Multiply 10^6 to make colormap index short
    
    sphere = get_sphere('symmetric724')
    odf = dsifit.odf(sphere, 2);
    r = fvtk.ren();
    fvtk.add(r, fvtk.sphere_funcs(odf, sphere));
    fvtk.show(r)
# Out:
# ---------------------------------------------------------------------------
# TripWireError                             Traceback (most recent call last)
# <ipython-input-19-b4544897ef4a> in <module>()
#      16     sphere = get_sphere('symmetric724')
#      17     odf = dsifit.odf(sphere, 2);
# ---> 18     r = fvtk.ren();
#      19     fvtk.add(r, fvtk.sphere_funcs(odf, sphere));
#      20     fvtk.show(r)
#
# /usr/local/anaconda/lib/python2.7/site-packages/dipy/viz/fvtk.pyc in ren()
#      78     >>> #fvtk.show(r)
#      79     '''
# ---> 80     return vtk.vtkRenderer()
#      81
#      82
#
# /usr/local/anaconda/lib/python2.7/site-packages/dipy/utils/tripwire.pyc in __getattr__(self, attr_name)
#      46     def __getattr__(self, attr_name):
#      47         ''' Raise informative error accessing attributes '''
# ---> 48         raise TripWireError(self._msg)
#
# TripWireError: We need package vtk for these functions, but ``import vtk`` raised an ImportError

# %%
pdf.shape
# Out:
# (1, 4, 2, 201, 201, 201)

# %%
qgridsz = 201;

for ii in np.arange(files.shape[0]):
    filename = files[ii]
    data = dst.loaddata(filename);
    gtab = dst.loadgtab(filename);
    fov, mdd = dst.loadstat(filename);
    pdfroi, pdfslicestart, pdfsliceend, camerapos = dst.loadroi(filename, qgridsz);
    
    hannwidth = np.inf;
    integdistance = mdd
    rend = np.round(integdistance / fov * qgridsz);
    dsimodel = dsi.DiffusionSpectrumModel(gtab, qgrid_size=qgridsz, filter_width=hannwidth, r_start=0, r_end=rend, r_step=0.2);
    dsifit = dsimodel.fit(data);
    pdf = dsifit.pdf();
    pdf = pdf / pdf.sum() * 10**6; #pdf sums to 1. Multiplying 10^6 to make colormap index short

            
    # save pdf
    pdfslice = pdf[pdfroi[0], pdfroi[1], pdfroi[2]][pdfslicestart[0]:pdfsliceend[0], pdfslicestart[1]:pdfsliceend[1], pdfslicestart[2]:pdfsliceend[2]];
    pdfslice = np.squeeze(pdfslice);
    
    figure();
    imshow(pdfslice);
    circle = Circle((qgridsz//2, qgridsz//2), radius = rend, color = 'r', fill=False, linestyle = 'dashed', linewidth=3.)
    gca().add_artist(circle)
    axis('off');
    colorbar();
    pdfname = 'figure/figure2/' + filename + '_pdf.png';
    savefig(pdfname, dpi = 200)
