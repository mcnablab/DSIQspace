# %%
import numpy as np
import nibabel as nib
import dsiadapt as dsi
from dipy.viz import fvtk
from dipy.data import get_sphere
import dsitool as dst

# %pylab inline
np.set_printoptions(threshold=numpy.nan)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# Load ODF sphere directions
sphere = get_sphere('symmetric724')
sphere = sphere.subdivide(2)

# %%
files = np.array(['DSI11_invivo_roi', 'DSI11_exvivo_roi'])

# %%
# Load fov and mdd needed for ODF reconstruction
# fov and mdd data are generated by script s-figure2-pdf
# The four elements are in order to in vivo DSI11, ex vivo DSI11, ex vivo DSI15, ex vivo DSI17
fovarr = np.load('results/fov.npy');
mddarr = np.load('results/mdd.npy');

# %%
qgridsz = 201;
pdfweight = np.array([2, 8]);

for ii in np.arange(files.shape[0]):
    filename = files[ii]
    data = dst.loaddata(filename);
    gtab = dst.loadgtab(filename);
    fov = fovarr[ii];
    mdd = mddarr[ii];
    #pdfroi, pdfslicestart, pdfsliceend, camerapos = dst.loadroi(filename, qgridsz);
    hannwidth = np.inf;
    integdist = mdd;
    rend = np.round(integdist / fov * qgridsz);
    
    dsimodel = dsi.DiffusionSpectrumModel(gtab, qgrid_size=qgridsz, filter_width=hannwidth, r_start=0, r_end=rend, r_step=0.2);
    dsifit = dsimodel.fit(data);
    odf = dsifit.odf(sphere, pdfweight[ii]);
            
    # save odf
    r = fvtk.ren();
    fvtk.add(r, fvtk.sphere_funcs(odf, sphere));
    odfname = 'figure/figure6/' + filename + '_odf_hann_' + str(hannwidth) + '_integdist_' + str(integdist) + '_pdfweight_' + str(pdfweight[ii]) + '.png';
    fvtk.record(r, n_frames=1, out_path=odfname, size=(1600,1000))
    #fvtk.show(r)
# Out:
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/home/qytian/Canopy/appdata/canopy-1.0.3.1262.rh5-x86_64/lib/python2.7/site-packages/IPython/core/ultratb.py", line 758, in structured_traceback
#     records = _fixed_getinnerframes(etb, context, tb_offset)
#   File "/home/qytian/Canopy/appdata/canopy-1.0.3.1262.rh5-x86_64/lib/python2.7/site-packages/IPython/core/ultratb.py", line 241, in _fixed_getinnerframes
#     records  = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/qytian/Canopy/appdata/canopy-1.0.3.1262.rh5-x86_64/lib/python2.7/inspect.py", line 1043, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
#   File "/home/qytian/Canopy/appdata/canopy-1.0.3.1262.rh5-x86_64/lib/python2.7/inspect.py", line 1003, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/qytian/Canopy/appdata/canopy-1.0.3.1262.rh5-x86_64/lib/python2.7/inspect.py", line 454, in getsourcefile
#     if hasattr(getmodule(object, filename), '__loader__'):
#   File "/home/qytian/Canopy/appdata/canopy-1.0.3.1262.rh5-x86_64/lib/python2.7/inspect.py", line 497, in getmodule
#     f = getabsfile(module)
#   File "/home/qytian/Canopy/appdata/canopy-1.0.3.1262.rh5-x86_64/lib/python2.7/inspect.py", line 466, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/qytian/Canopy/appdata/canopy-1.0.3.1262.rh5-x86_64/lib/python2.7/inspect.py", line 451, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/qytian/Canopy/appdata/canopy-1.0.3.1262.rh5-x86_64/lib/python2.7/genericpath.py", line 18, in exists
#     os.stat(path)
# KeyboardInterrupt
# ERROR: Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# Unfortunately, your original traceback can not be constructed.
